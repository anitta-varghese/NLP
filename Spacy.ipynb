# %% [markdown]
# <a href="https://colab.research.google.com/github/anitta-varghese/NLP/blob/main/Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from collections import Counter
from heapq import nlargest

nlp = spacy.load('en_core_web_sm')

introduction_text = ('Python is one of the most popular programming languages in the world. '
 'It is known for its simplicity, readability, and versatility. '
 'Python supports multiple programming paradigms, including object-oriented and functional programming. '
 'It is widely used in data science, machine learning, and artificial intelligence. '
 'Python has an extensive collection of libraries and frameworks like NumPy, Pandas, and TensorFlow. '
 'It powers many web applications through frameworks such as Django and Flask. '
 'Python is an open-source language maintained by a large global community. '
 'It is used by top companies like Google, Netflix, and NASA for various applications. '
 'Python is highly portable and can run on Windows, macOS, and Linux. '
 'Its ease of integration with other technologies makes it ideal for modern software development.')


doc = nlp(introduction_text)

print("1. Keywords ==============================================")
keyword = []
stopwords = list(STOP_WORDS)
pos_tag = ['PROPN', 'ADJ', 'NOUN', 'VERB']

for token in doc:
    if token.text in stopwords or token.text in punctuation:
        continue
    if token.pos_ in pos_tag:
        keyword.append(token.text)

print(keyword)
freq_word = Counter(keyword)
print(freq_word.most_common(5))

print("\n2. Sentence Strength =====================================")
sent_strength = {}
for sent in doc.sents:
    for word in sent:
        if word.text in freq_word.keys():
            if sent in sent_strength.keys():
                sent_strength[sent] += freq_word[word.text]
            else:
                sent_strength[sent] = freq_word[word.text]

print(sent_strength)

print("\n3. Summary ===============================================")
summarized_sentences = nlargest(3, sent_strength, key=sent_strength.get)
for sent in summarized_sentences:
    print(f"- {sent.text}")
# Out:
# 1. Keywords ==============================================
# ['Python', 'popular', 'programming', 'languages', 'world', 'known', 'simplicity', 'readability', 'versatility', 'Python', 'supports', 'multiple', 'programming', 'paradigms', 'including', 'object', 'oriented', 'functional', 'programming', 'data', 'science', 'machine', 'learning', 'artificial', 'intelligence', 'Python', 'extensive', 'collection', 'libraries', 'frameworks', 'NumPy', 'Pandas', 'TensorFlow', 'powers', 'web', 'applications', 'frameworks', 'Django', 'Flask', 'Python', 'open', 'source', 'language', 'maintained', 'large', 'global', 'community', 'companies', 'Google', 'Netflix', 'NASA', 'applications', 'Python', 'portable', 'run', 'Windows', 'macOS', 'Linux', 'ease', 'integration', 'technologies', 'makes', 'ideal', 'modern', 'software', 'development']
# [('Python', 5), ('programming', 3), ('frameworks', 2), ('applications', 2), ('popular', 1)]
#
# 2. Sentence Strength =====================================
# ...
